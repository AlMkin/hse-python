# %%
documents = [
    {'type': 'passport', 'number': '2207 876234', 'name': 'Василий Гупкин'},
    {'type': 'invoice', 'number': '11-2', 'name': 'Геннадий Покемонов'},
    {'type': 'insurance', 'number': '10006', 'name': 'Аристарх Павлов'}
]

directories = {
    '1': ['2207 876234', '11-2'],
    '2': ['10006'],
    '3': []
}

def find_owner_by_doc_number(doc_number):
    for doc in documents:
        if doc['number'] == doc_number:
            return doc['name']
    return None

def find_shelf_by_doc_number(doc_number):
    for shelf, docs in directories.items():
        if doc_number in docs:
            return shelf
    return None

def main():
    while True:
        command = input("Введите команду (p - найти владельца, s - найти полку, q - выход): ").strip().lower()
        
        if command == 'q':
            print("Программа завершена.")
            break

        elif command == 'p':
            doc_number = input("Введите номер документа: ").strip()
            owner = find_owner_by_doc_number(doc_number)
            if owner:
                print(f"Владелец документа: {owner}")
            else:
                print("Документ не найден.")

        elif command == 's':
            doc_number = input("Введите номер документа: ").strip()
            shelf = find_shelf_by_doc_number(doc_number)
            if shelf:
                print(f"Документ хранится на полке: {shelf}")
            else:
                print("Документ не найден.")

        else:
            print("Неизвестная команда. Попробуйте снова.")

if __name__ == "__main__":
    main()
# Out:
# Введите команду (p - найти владельца, s - найти полку, q - выход):  p
# Введите номер документа:  10006
# Владелец документа: Аристарх Павлов
# Введите команду (p - найти владельца, s - найти полку, q - выход):  s
# Введите номер документа:  11-2
# Документ хранится на полке: 1
# Введите команду (p - найти владельца, s - найти полку, q - выход):  q
# Программа завершена.
