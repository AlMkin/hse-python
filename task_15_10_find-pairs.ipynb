# %%
def find_pairs(boys, girls):
    boys_sorted = sorted(boys)
    girls_sorted = sorted(girls)
    
    if len(boys_sorted) != len(girls_sorted):
        return "Внимание, кто-то может остаться без пары."
    
    pairs = []
    for boy, girl in zip(boys_sorted, girls_sorted):
        pairs.append(f"{boy} и {girl}")
    
    return "Идеальные пары:\n" + "\n".join(pairs)

boys1 = ['Peter', 'Alex', 'John', 'Arthur', 'Richard']
girls1 = ['Kate', 'Liza', 'Kira', 'Emma', 'Trisha']

boys2 = ['Peter', 'Alex', 'John', 'Arthur', 'Richard', 'Michael']

print(find_pairs(boys1, girls1))

print(find_pairs(boys2, girls1))
# Out:
# Идеальные пары:
# Alex и Emma
# Arthur и Kate
# John и Kira
# Peter и Liza
# Richard и Trisha
# Внимание, кто-то может остаться без пары.
